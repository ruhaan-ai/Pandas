# %% [markdown]
# <a href="https://colab.research.google.com/github/ruhaan-ai/Pandas/blob/main/PivotTables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Pivot Tables

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    881     10   John  January      Q1
# 1  2023-01-02       B   West    491     83   Mary  January      Q1
# 2  2023-01-03       C  North    987     37    Bob  January      Q1
# 3  2023-01-04       D  South    715     75  Alice  January      Q1
# 4  2023-01-05       A   East    502     59   John  January      Q1
# 5  2023-01-06       B   West    553     47   Mary  January      Q1
# 6  2023-01-07       C  North    775     72    Bob  January      Q1
# 7  2023-01-08       D  South    846     98  Alice  January      Q1
# 8  2023-01-09       A   East    113     76   John  January      Q1
# 9  2023-01-10       B   West    897     51   Mary  January      Q1
# 10 2023-01-11       C  North    546     57    Bob  January      Q1
# 11 2023-01-12       D  South    544     97  Alice  January      Q1
# 12 2023-01-13       A   East    581     75   John  January      Q1
# 13 2023-01-14       B   West    823     97   Mary  January      Q1
# 14 2023-01-15       C  North    720     45    Bob  January      Q1
# 15 2023-01-16       D  South    968     65  Alice  January      Q1
# 16 2023-01-17       A   East    265     90   John  January      Q1
# 17 2023-01-18       B   West    346     38   Mary  January      Q1
# 18 2023-01-19       C  North    768     57    Bob  January      Q1
# 19 2023-01-20       D  South    104     30  Alice  January      Q1

# %%
pd.pivot_table(df,values='Sales',index='Region',columns='Month',aggfunc='sum')
# Out:
# Month   January
# Region
# East       2342
# North      3796
# South      3177
# West       3110

# %%
pivot2=pd.pivot_table(df,values=['Sales','Units'], index='Region', columns='Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     468.4    NaN    NaN    NaN  62.0   NaN   NaN   NaN
# North      NaN    NaN  759.2    NaN   NaN   NaN  53.6   NaN
# South      NaN    NaN    NaN  635.4   NaN   NaN   NaN  73.0
# West       NaN  622.0    NaN    NaN   NaN  63.2   NaN   NaN

# %% [markdown]
# Cross Tabs

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
